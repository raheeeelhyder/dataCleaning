# %%
import pandas as pd
import numpy as np

# %%
ds = pd.read_csv("flicker.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/3322515901.py in <module>
# ----> 1 ds = pd.read_csv("flicker.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
ds = pd.read_csv("datasets/flicker.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/2849889980.py in <module>
# ----> 1 ds = pd.read_csv("datasets/flicker.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
ds = pd.read_csv("flicker.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/2787091076.py in <module>
# ----> 1 ds = pd.read_csv("flicker.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df = pd.read_csv("F:\introduction-to-tableau\Datasources\Chapter 1")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/1940806020.py in <module>
# ----> 1 df = pd.read_csv("F:\introduction-to-tableau\Datasources\Chapter 1")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data= pd.read_ csv(flicker.csv,   error_ bad_ lines=False)
# Out:
#   File "C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/469820541.py", line 1
#     data= pd.read_ csv(flicker.csv,   error_ bad_ lines=False)
#                    ^
# SyntaxError: invalid syntax

# %%
# Out:
#    Unnamed: 0    id       neighbourhood  latitude  longitude        room_type  \
# 0           0  2595             Midtown  40.75362  -73.98377  Entire home/apt
# 1           1  3831            Brooklyn  40.68514  -73.95976  Entire home/apt
# 2           2  5099           Manhattan  40.74767  -73.97500  Entire home/apt
# 3           3  5121  Bedford-Stuyvesant  40.68688  -73.95596     Private room
# 4           4  5178           Manhattan  40.76489  -73.98493     Private room
#
#     price  days_occupied_in_2019  minimum_nights  number_of_reviews  \
# 0  225.00                   15.0              10                 48
# 1   89.00                  188.0               1                295
# 2  200.00                  362.0               3                 78
# 3   60.00                    0.0              29                 49
# 4   79.00                  141.0               2                454
#
#    reviews_per_month  availability_2020
# 0               0.39                  1
# ...

# %%
data= pd.read_ csv('flicker.csv',   error_ bad_ lines=False)
# Out:
#   File "C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/2913747750.py", line 1
#     data= pd.read_ csv('flicker.csv',   error_ bad_ lines=False)
#                    ^
# SyntaxError: invalid syntax

# %%
ds = pd.read_excw("flicker.csv",   quoting=csv.QUOTE_ NONE)
# Out:
#   File "C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/3211111734.py", line 1
#     ds = pd.read_csv("flicker.csv",   quoting=csv.QUOTE_ NONE)
#                                                          ^
# SyntaxError: invalid syntax

# %%
ds = pd.read_csv('flicker.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/1523568972.py in <module>
# ----> 1 ds = pd.read_csv('flickers.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
ds = pd.read_csv('flicker.csv', error_bad_lines = False )
# Out:
# C:\Users\Raheel Haider\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/1748155500.py in <module>
# ----> 1 ds = pd.read_csv('flicker.csv', error_bad_lines = False )
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
pd.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/3405423208.py in <module>
# ----> 1 pd.head()
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'head'

# %%
andas.read_csv(flicker.csv, sep=', ', delimiter=None, 
                header='infer', names=None, 
                index_col=None, usecols=None, squeeze=False, 
                ..., engine=None)
# Out:
#   File "C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/1544111286.py", line 4
#     ..., engine=None)
#                     ^
# SyntaxError: positional argument follows keyword argument

# %%
# Out:
#   File "C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/183299170.py", line 4
#     ..., engine=None, ...)
#                          ^
# SyntaxError: positional argument follows keyword argument

# %%
ds  = pd.read_csv('flicker.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/2192216912.py in <module>
# ----> 1 ds  = pd.read_csv('flicker.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df = pd.read_csv(flicker.csv, delimiter='\n', header=None, encoding='utf-8', quoting=csv.QUOTE_NONE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/681391639.py in <module>
# ----> 1 df = pd.read_csv(flicker.csv, delimiter='\n', header=None, encoding='utf-8', quoting=csv.QUOTE_NONE)
#
# NameError: name 'flicker' is not defined

# %%
df = pd.read_csv('flicker.csv', delimiter='\n', header=None, encoding='utf-8', quoting=csv.QUOTE_NONE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/745554777.py in <module>
# ----> 1 df = pd.read_csv('flicker.csv', delimiter='\n', header=None, encoding='utf-8', quoting=csv.QUOTE_NONE)
#
# NameError: name 'csv' is not defined

# %%
df = pd.read_csv(('flicker.csv',  quoting=csv.QUOTE_NONE)
# Out:
#   File "C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/3166513894.py", line 1
#     df = pd.read_csv(('flicker.csv',  quoting=csv.QUOTE_NONE)
#                                              ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv("flicker.csv")

# %%
df.head()
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
to_drop = ['Edition Statement', "Corporate Author", 'Corporate Contributors', "Former owner", "Engraver", 'Issuance type', "Shelfmarks"]
df.drop(to_drop, inplace = True  ,  axis = 1 )

# %%
pd.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/3405423208.py in <module>
# ----> 1 pd.head()
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'head'

# %%
df.head()
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                  Contributors  \
# 0      A. A.                               FORBES, Walter.
# ...

# %%
df.drop(columns = to_drop, inplace = True )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8656/3506044843.py in <module>
# ----> 1 df.drop(columns = to_drop, inplace = True )
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df['Identifier'].is_unique
# Out:
# True

# %%
df =  df.set_index('Identifier')
df.head()
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London         1879 [1878]
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# ...

# %%
df.head(10)
# Out:
#                            Place of Publication Date of Publication  \
# Identifier
# 206                                      London         1879 [1878]
# 216                    London; Virtue & Yorston                1868
# 218                                      London                1869
# 472                                      London                1851
# 480                                      London                1857
# 481                                      London                1875
# 519                                      London                1872
# 667         pp. 40. G. Bryan & Co: Oxford, 1898                 NaN
# 874                                     London]                1676
# 1143                                     London                1679
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# ...

# %%
df.loc[874]
# Out:
# Place of Publication                                              London]
# Date of Publication                                                  1676
# Publisher                                                             NaN
# Title                   A Warning to the inhabitants of England, and L...
# Author                                                             Remaʿ.
# Contributors                                                 ADAMS, Mary.
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Name: 874, dtype: object

# %%
df.get_dtype_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8448/3335330908.py in <module>
# ----> 1 df.get_dtype_counts()
#
# NameError: name 'df' is not defined

# %%
df.get_dtype_counts(ascii)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8448/3335330908.py in <module>
# ----> 1 df.get_dtype_counts()
#
# NameError: name 'df' is not defined

# %%
df.loc[874]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8448/1507850684.py in <module>
# ----> 1 df.loc[874]
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv("flicker.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8448/411755254.py in <module>
# ----> 1 df = pd.read_csv("flicker.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd 
import numpy as np
df = pd.read_csv("flicker.csv")
df.head(10)
# Out:
#    Identifier              Edition Statement  \
# 0         206                            NaN
# 1         216                            NaN
# 2         218                            NaN
# 3         472                            NaN
# 4         480   A new edition, revised, etc.
# 5         481  Fourth edition, revised, etc.
# 6         519                            NaN
# 7         667                            NaN
# 8         874                            NaN
# 9        1143                            NaN
#
#                   Place of Publication Date of Publication  \
# 0                               London         1879 [1878]
# 1             London; Virtue & Yorston                1868
# 2                               London                1869
# 3                               London                1851
# 4                               London                1857
# 5                               London                1875
# ...

# %%
df = df.set_index('Identifier')
df.head(10)
# Out:
#                         Edition Statement  \
# Identifier
# 206                                   NaN
# 216                                   NaN
# 218                                   NaN
# 472                                   NaN
# 480          A new edition, revised, etc.
# 481         Fourth edition, revised, etc.
# 519                                   NaN
# 667                                   NaN
# 874                                   NaN
# 1143                                  NaN
#
#                            Place of Publication Date of Publication  \
# Identifier
# 206                                      London         1879 [1878]
# 216                    London; Virtue & Yorston                1868
# 218                                      London                1869
# 472                                      London                1851
# 480                                      London                1857
# ...

# %%
to_drop = ['Contributors',	'Corporate Author',	'Corporate Contributors',	'Former owner',	'Engraver', 'Issuance type', 'Shelfmarks']
df.drop(columns =  to_drop, axis = True )
# Out:
#                        Edition Statement      Place of Publication  \
# Identifier
# 206                                  NaN                    London
# 216                                  NaN  London; Virtue & Yorston
# 218                                  NaN                    London
# 472                                  NaN                    London
# 480         A new edition, revised, etc.                    London
# ...                                  ...                       ...
# 128110                               NaN                    London
# 128995                               NaN                    London
# 130629                               NaN                    London
# 130655                               NaN                    London
# 131442                               NaN                    London
#
#            Date of Publication              Publisher  \
# Identifier
# 206                1879 [1878]       S. Tinsley & Co.
# ...

# %%
df.get_dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8448/1292414119.py in <module>
# ----> 1 df.get_dtype()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_dtype'

# %%
df.get_dtype_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8448/3335330908.py in <module>
# ----> 1 df.get_dtype_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_dtype_counts'

# %%
df.get_dtypes.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8448/1916582396.py in <module>
# ----> 1 df.get_dtypes.value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_dtypes'

# %%
df.dtypes.value_counts()
# Out:
# object     10
# float64     4
# dtype: int64

# %%
regex = r'^(\d{4})'

# %%
extr = df['Date of Publication'].str.extract(r'^(\d{4})', expand=False)
extr.head()
# Out:
# Identifier
# 206    1879
# 216    1868
# 218    1869
# 472    1851
# 480    1857
# Name: Date of Publication, dtype: object

# %%
extr.dtypes.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8448/1307066923.py in <module>
# ----> 1 extr.dtypes.value_counts()
#
# AttributeError: 'numpy.dtype[object_]' object has no attribute 'value_counts'

# %%
extr.dtypes.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8448/1307066923.py in <module>
# ----> 1 extr.dtypes.value_counts()
#
# AttributeError: 'numpy.dtype[object_]' object has no attribute 'value_counts'

# %%
extr.dtypes.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8448/1307066923.py in <module>
# ----> 1 extr.dtypes.value_counts()
#
# AttributeError: 'numpy.dtype[object_]' object has no attribute 'value_counts'

# %%
df.dtypes.value_counts()
# Out:
# object     10
# float64     4
# dtype: int64

# %%
extr.dtypes.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RAHEEL~1\AppData\Local\Temp/ipykernel_8448/1307066923.py in <module>
# ----> 1 extr.dtypes.value_counts()
#
# AttributeError: 'numpy.dtype[object_]' object has no attribute 'value_counts'

# %%
df['Date of Publication'] = pd.to_numeric(extr)

# %%
df["Date of Publication"].dtypes
# Out:
# dtype('float64')

# %%
df["Place of Publication"].head(20)
# Out:
# Identifier
# 206                                  London
# 216                London; Virtue & Yorston
# 218                                  London
# 472                                  London
# 480                                  London
# 481                                  London
# 519                                  London
# 667     pp. 40. G. Bryan & Co: Oxford, 1898
# 874                                 London]
# 1143                                 London
# 1280                               Coventry
# 1808                            Christiania
# 1905                                Firenze
# 1929                              Amsterdam
# 2836                                 Savona
# 2854                                 London
# 2956                                  Paris
# 2957                                  Paris
# 3017                            Puerto-Rico
# 3131                               New York
# Name: Place of Publication, dtype: object

# %%
pub = df['Place of Publication'] 
london = pub.str.contains("London")
london[:5]
# Out:
# Identifier
# 206    True
# 216    True
# 218    True
# 472    True
# 480    True
# Name: Place of Publication, dtype: bool

# %%
oxford = pub.str.contains("Oxford")

# %%
oxford[:10]
# Out:
# Identifier
# 206     False
# 216     False
# 218     False
# 472     False
# 480     False
# 481     False
# 519     False
# 667      True
# 874     False
# 1143    False
# Name: Place of Publication, dtype: bool

# %%
df['Place of Publication'] = np.where(london, "London", np.where(oxford, "Oxford", pub.str.replace("-", " ")))

# %%
df.head(20)
# Out:
#                                             Edition Statement  \
# Identifier
# 206                                                       NaN
# 216                                                       NaN
# 218                                                       NaN
# 472                                                       NaN
# 480                              A new edition, revised, etc.
# 481                             Fourth edition, revised, etc.
# 519                                                       NaN
# 667                                                       NaN
# 874                                                       NaN
# 1143                                                      NaN
# 1280                                                      NaN
# 1808                                                      NaN
# 1905                                                      NaN
# 1929                                                      NaN
# ...

# %%
df.head()
# Out:
#            Place of Publication  Date of Publication              Publisher  \
# Identifier
# 206                      London               1879.0       S. Tinsley & Co.
# 216                      London               1868.0           Virtue & Co.
# 218                      London               1869.0  Bradbury, Evans & Co.
# 472                      London               1851.0          James Darling
# 480                      London               1857.0   Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# 480         [The World in which I live, and my place in it...  A., E. S.
#
# ...

# %%
university_towns = []
with open("University_towns.txt") as file: 
    for line in file: 
        if "[edit]" in line:
            state = line
        else:
                university_towns.append((state, line ))
university_towns[:5]
# Out:
# [('Alabama[edit]\n', 'Auburn (Auburn University)[1]\n'),
#  ('Alabama[edit]\n', 'Florence (University of North Alabama)\n'),
#  ('Alabama[edit]\n', 'Jacksonville (Jacksonville State University)[2]\n'),
#  ('Alabama[edit]\n', 'Livingston (University of West Alabama)[2]\n'),
#  ('Alabama[edit]\n', 'Montevallo (University of Montevallo)[2]\n')]

# %%
town_state = pd.DataFrame(university_towns, columns = ["State", "Towns"])

# %%
university_towns[:5]
# Out:
# [('Alabama[edit]\n', 'Auburn (Auburn University)[1]\n'),
#  ('Alabama[edit]\n', 'Florence (University of North Alabama)\n'),
#  ('Alabama[edit]\n', 'Jacksonville (Jacksonville State University)[2]\n'),
#  ('Alabama[edit]\n', 'Livingston (University of West Alabama)[2]\n'),
#  ('Alabama[edit]\n', 'Montevallo (University of Montevallo)[2]\n')]

# %%
town_state.head(5)
# Out:
#              State                                              Towns
# 0  Alabama[edit]\n                    Auburn (Auburn University)[1]\n
# 1  Alabama[edit]\n           Florence (University of North Alabama)\n
# 2  Alabama[edit]\n  Jacksonville (Jacksonville State University)[2]\n
# 3  Alabama[edit]\n       Livingston (University of West Alabama)[2]\n
# 4  Alabama[edit]\n         Montevallo (University of Montevallo)[2]\n

# %%
def get_citystate(item):
...     if ' (' in item:
...         return item[:item.find(' (')]
...     elif '[' in item:
...         return item[:item.find('[')]
...     else:
...         return item

# %%
town_state = town_state.applymap(get_citystate)

# %%
town_state.head()
# Out:
#      State         Towns
# 0  Alabama        Auburn
# 1  Alabama      Florence
# 2  Alabama  Jacksonville
# 3  Alabama    Livingston
# 4  Alabama    Montevallo

# %%
olympics_df = pd.read_csv("olympics.csv")

# %%
olympics_df.head(10)
# Out:
#                            0         1     2     3     4      5         6  \
# 0                        NaN  ? Summer  01 !  02 !  03 !  Total  ? Winter
# 1          Afghanistan (AFG)        13     0     0     2      2         0
# 2              Algeria (ALG)        12     5     2     8     15         3
# 3            Argentina (ARG)        23    18    24    28     70        18
# 4              Armenia (ARM)         5     1     2     9     12         6
# 5    Australasia (ANZ) [ANZ]         2     3     4     5     12         0
# 6  Australia (AUS) [AUS] [Z]        25   139   152   177    468        18
# 7              Austria (AUT)        26    18    33    35     86        22
# 8           Azerbaijan (AZE)         5     6     5    15     26         5
# 9              Bahamas (BAH)        15     5     2     5     12         0
#
#       7     8     9     10       11    12    13    14              15
# 0  01 !  02 !  03 !  Total  ? Games  01 !  02 !  03 !  Combined total
# ...

# %%
olympics_df = pd.read_csv("olympics.csv", header = 1)

# %%
olympics_df.head(10)
# Out:
#                   Unnamed: 0  ? Summer  01 !  02 !  03 !  Total  ? Winter  \
# 0          Afghanistan (AFG)        13     0     0     2      2         0
# 1              Algeria (ALG)        12     5     2     8     15         3
# 2            Argentina (ARG)        23    18    24    28     70        18
# 3              Armenia (ARM)         5     1     2     9     12         6
# 4    Australasia (ANZ) [ANZ]         2     3     4     5     12         0
# 5  Australia (AUS) [AUS] [Z]        25   139   152   177    468        18
# 6              Austria (AUT)        26    18    33    35     86        22
# 7           Azerbaijan (AZE)         5     6     5    15     26         5
# 8              Bahamas (BAH)        15     5     2     5     12         0
# 9              Bahrain (BRN)         8     0     0     1      1         0
#
#    01 !.1  02 !.1  03 !.1  Total.1  ? Games  01 !.2  02 !.2  03 !.2  \
# 0       0       0       0        0       13       0       0       2
# ...

# %%
new_names =  {'Unnamed: 0': 'Country',
               '? Summer': 'Summer Olympics',
               '01 !' :'Gold',
               '02 !': 'Silver',
               '03 !': 'Bronze',
               '? Winter': 'Winter Olympics',
               '01 !.1': 'Gold.1',
               '02 !.1': 'Silver.1',
               '03 !.1': 'Bronze.1',
               '? Games': '# Games',
               '01 !.2': 'Gold.2',
               '02 !.2': 'Silver.2',
               '03 !.2': 'Bronze.2'}

# %%
olympics_df.rename(columns = new_names, inplace = True )

# %%
olympics_df.head(10)
# Out:
#                      Country  Summer Olympics  Gold  Silver  Bronze  Total  \
# 0          Afghanistan (AFG)               13     0       0       2      2
# 1              Algeria (ALG)               12     5       2       8     15
# 2            Argentina (ARG)               23    18      24      28     70
# 3              Armenia (ARM)                5     1       2       9     12
# 4    Australasia (ANZ) [ANZ]                2     3       4       5     12
# 5  Australia (AUS) [AUS] [Z]               25   139     152     177    468
# 6              Austria (AUT)               26    18      33      35     86
# 7           Azerbaijan (AZE)                5     6       5      15     26
# 8              Bahamas (BAH)               15     5       2       5     12
# 9              Bahrain (BRN)                8     0       0       1      1
#
#    Winter Olympics  Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# ...
